# %%
import PySide2

# %%
from DAVE.scene import *
# Out:
# default resource folders:
# C:\data\Dave\Public\DAVE\src\DAVE\resources
# C:\Users\beneden\DAVE_models
# Blender found at: C:\Program Files\Blender Foundation\Blender 2.82\blender.exe

# %%
from DAVE.gui.main import Gui
# Out:
# embedWindow(verbose=True): could not load k3d module, try:
# > pip install k3d      # and if necessary:
# > conda install nodejs

# %%
s = Scene()

# %%
Gui(s)
# Out:
# Creating Node Tree
# Creating Derived Properties
# Creating Properties
# Creating Selection Actions
# selecting a node with name demo
# ...
# closing
# closing
# closing
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\data\Dave\Public\DAVE\src\DAVE\gui\main.py in onClose(self)
#     640
#     641     def onClose(self):
# --> 642         self.visual.shutdown_qt()
#     643         # self._logfile.close()
#     644         print('closing')
#
# C:\data\Dave\Public\DAVE\src\DAVE\visual.py in shutdown_qt(self)
#    1271         """Stops the renderer such that the application can close without issues"""
#    1272
# -> 1273         if self.vtkWidget:
#    1274             ren = self.vtkWidget.GetRenderWindow()
#    1275             iren = ren.GetInteractor()
#
# AttributeError: 'Viewport' object has no attribute 'vtkWidget'

# %%
s.new_rigidbody('demo')

# %%
s.print_node_tree()
# Out:
# demo [RigidBody]
#  |-> Axis [Axis]
