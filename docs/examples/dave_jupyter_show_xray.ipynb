# %%
from sys import path

# %%
path.append(r'C:\data\Dave\Public\DAVE\src')

# %%
from DAVE import *
# Out:
# DAVEcore version = 2.0 from C:\data\vf\pyo3d\x64\Release\DAVEcore.cp311-win_amd64.pyd
# Blender found at: C:\Users\beneden\AppData\Local\Microsoft\WindowsApps\\blender-launcher.exe
#
# Loading DAVE...

# %%
from DAVE.jupyter import *
from DAVE.visual import create_momentline_actors, create_shearline_actors

# %%
s = Scene()
s.new_frame('basis')
s.new_visual('box','res: cube.obj', parent='basis')


show(s, camera_pos = (6,6,3),
     lookat = (0,0,0),
     painters='Visual',
     zoom_fit = False)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x600>

# %%
show(s, camera_pos = (6,4,3),
     lookat = (0,0,0),
     painters='X-ray',
     geometry_scale=0,
     zoom_fit = False)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x600>

# %%
show(s, camera_pos = (6,4,3),
     lookat = (0,0,0),
     painters='X-ray',
     geometry_scale=0,
     zoom_fit = True)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x600>

# %%
show(s, camera_pos = (6,4,0),
     lookat = (5,0,0),
     zoom_fit = False)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x600>

# %%
P
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 P
#
# NameError: name 'P' is not defined

# %%
P.show()

# %%
P.camera
