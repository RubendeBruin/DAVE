# %%
from DAVE import *
# Out:
# Equilibrium-core version = 1.96
# default resource folders:
# C:\data\Dave\Public\DAVE\src\DAVE\resources
# C:\Users\beneden\DAVE_models
# C:\data\Dave\Public\DAVE\docs\examples
# Blender found at: C:\Program Files\Blender Foundation\Blender 2.93\blender.exe

# %%
from DAVE.jupyter import *
from DAVE.visual import create_momentline_actors, create_shearline_actors
# Out:
# embedWindow(verbose=True): could not load ipyvtk_simple try:
# > pip install -U git+https://github.com/Kitware/ipyvtk-simple.git

# %%
s = Scene()
s.new_frame('basis')
s.new_visual('box','res: cube.obj', parent='basis')


show(s, camera_pos = (6,6,3),
     lookat = (0,0,0),
     painters='Visual',
     zoom_fit = False)
# Out:
# <PIL.Image.Image image mode=RGB size=3072x1800 at 0x2152819D5B0>

# %%
show(s, camera_pos = (6,4,3),
     lookat = (0,0,0),
     painters='X-ray',
     geometry_scale=0,
     zoom_fit = False)
# Out:
# <PIL.Image.Image image mode=RGB size=3072x1800 at 0x21537045160>
